# %%
# 导入相关包
import cv2
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi']=200

# %%
# 读取图片
img = cv2.imread('./images/faces2.jpg')
# MTCNN需要rgb通道顺序
img_cvt = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)

# %%
# 导入MTCNN
from mtcnn.mtcnn import MTCNN
# 加载模型
face_detector = MTCNN()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 导入MTCNN
# ----> 2 from mtcnn.mtcnn import MTCNN
#       3 # 加载模型
#       4 face_detector = MTCNN()
#
# ModuleNotFoundError: No module named 'mtcnn'

# %%
# 检测人脸
detections = face_detector.detec_faces(img_cvt)
for face in detections:
    (x,y,w,h) = face['box']
    cv2.rectangle(img_cvt,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(img_cvt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 检测人脸
# ----> 2 detections = face_detector.detec_faces(img_cvt)
#       3 for face in detections:
#       4     (x,y,w,h) = face['box']
#
# NameError: name 'face_detector' is not defined

# %%
# 读取图片
img = cv2.imread('./images/test.jpg')
img_cvt = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)

#检测人脸
for face in detections:
    (x,y,w,h) = face['box']
    cv2.rectangle(img_cvt,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(img_cvt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 plt.imshow(img_cvt)
#       6 #检测人脸
# ----> 7 for face in detections:
#       8     (x,y,w,h) = face['box']
#       9     cv2.rectangle(img_cvt,(x,y),(x+w,y+h),(0,255,0),5)
#
# NameError: name 'detections' is not defined
