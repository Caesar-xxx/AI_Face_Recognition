# %%
# 导入包
import cv2
import numpy as np
import matplotlib.pyplot as plt
import dlib
from PIL import Image
# %matplotlib inline
# plt.rcParams['figure.dpi']=200

# %%
img1 = cv2.imread('./lqd2.jpg')

# %%
img2 = cv2.imread('./my2.jpg')

# %%
plt.imshow(img2)

# %%
img1  = cv2.resize(img1,(100,100))

# %%
plt.imshow(img1)

# %%
img2[100:200,400:500] = img1

# %%
plt.imshow(img2)
